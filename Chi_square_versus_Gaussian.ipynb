# %%
N = rnorm(1000000)
C = rchisq(1000000,1)

# %%
hist(C, col=2, xlim=c(0.3,7), ylim=c(0,1),border=F, prob=T,
main='Chi decays slower than Gaussian')
hist(N, add=T, border=F, prob=T)
lines(density(N), lwd=7, col='gray25')
lines(density(C), col='red', lwd=7)
# Out:
# Plot with title “Chi decays slower than Gaussian”
