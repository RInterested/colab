# %%
install.packages('rpart')
install.packages('rpart.plot')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# fROM https://youtu.be/XLNsl1Da5MA
# This is an exmple of regression trees and plotting applied to the Iris dataset with a so-so plot at the end.

require(rpart)
g = runif(nrow(iris))
irisr = iris[order(g), ]
m3=rpart(Species ~ ., data = irisr[1:100, ], method = "class") # Training dataset
require(rpart.plot)
rpart.plot(m3, type = 3, extra = 101, fallen.leaves = T)
m3
p3 = predict(m3, irisr[101:150,], type = "class")
table(irisr[101:150, 5], predicted = p3)
# Out:
# Loading required package: rpart
#
# Loading required package: rpart.plot
#
# Warning message:
# “Bad 'data' field in model 'call' (expected a data.frame or a matrix).
# To silence this warning:
#     Call rpart.plot with roundint=FALSE,
#     or rebuild the rpart model with model=TRUE.”
# n= 100
#
# node), split, n, loss, yval, (yprob)
#       * denotes terminal node
#
# 1) root 100 64 versicolor (0.3100000 0.3600000 0.3300000)
#   2) Petal.Length< 2.6 31  0 setosa (1.0000000 0.0000000 0.0000000) *
#   3) Petal.Length>=2.6 69 33 versicolor (0.0000000 0.5217391 0.4782609)
#     6) Petal.Width< 1.75 41  5 versicolor (0.0000000 0.8780488 0.1219512) *
#     7) Petal.Width>=1.75 28  0 virginica (0.0000000 0.0000000 1.0000000) *
#             predicted
#              setosa versicolor virginica
#   setosa         19          0         0
#   versicolor      0         13         1
#   virginica       0          0        17
# plot without title
