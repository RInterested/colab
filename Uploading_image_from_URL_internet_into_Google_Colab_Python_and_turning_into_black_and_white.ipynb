# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
import scipy.fftpack as spfft
from   scipy.fft import fft, dct

from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression

from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image

# %%
# Create a list to store the urls of the images
urls = ['https://user-images.githubusercontent.com/9312897/117540238-3e6e1600-afdc-11eb-98ec-727b8629e2a7.png']
# Read and display the image
# loop over the image URLs, you could store several image urls in the list

for url in urls:
  image = io.imread(url)

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=138x118 at 0x7FEBF464B350>

# %%
# Turning the image into a black and white picture:
X = np.mean(image,-1);
