# %%
# !pip install rpy2==3.5.1 --quiet
# %load_ext rpy2.ipython

# %%
# %%R -w 1500 -h 500 -u px
#
# reg <- lm(mpg ~ wt, mtcars)
# par(mfrow = c(1,4))
# plot(reg, pch = 19)

# %%
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
import numpy as np

# %%
plt.rcParams["figure.figsize"] = (7,5)

x = np.linspace(0,10,100)

plt.plot(x, np.sin(x), linewidth=1.5)
plt.plot(x, np.cos(x), linewidth=1.5)
plt.plot(x, np.exp(-x), linewidth=1.5)
plt.plot(x, - 1/100 * x**2, linewidth=1.5)

plt.show()
