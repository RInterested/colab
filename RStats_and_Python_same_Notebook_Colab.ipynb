# %%
# !pip install rpy2==3.5.1 --quiet
# %load_ext rpy2.ipython

# %%
# %%R
#
# mod <- lm(mpg ~ wt, mtcars)
# summary(mod)
# Out:
# Call:
# lm(formula = mpg ~ wt, data = mtcars)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.5432 -2.3647 -0.1252  1.4096  6.8727
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  37.2851     1.8776  19.858  < 2e-16 ***
# wt           -5.3445     0.5591  -9.559 1.29e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.046 on 30 degrees of freedom
# Multiple R-squared:  0.7528,	Adjusted R-squared:  0.7446
# F-statistic: 91.38 on 1 and 30 DF,  p-value: 1.294e-10

# %%
# %%R -w 400 -h 400 -u px
# mod <- lm(mpg ~ wt, mtcars)
#
# plot(mpg ~ wt, mtcars, pch=19)
# abline(mod)

# %%
# %%R -w 1500 -h 500 -u px
#
# par(mfrow = c(1,4))
# plot(mod, pch = 19)

# %%
# %%R
#
# x = seq(-pi, pi,0.0001)
# plot(x, sin(x), type='l', lwd=2)

# %%
import matplotlib.pyplot as plt
# Different plotting styles: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
plt.style.use('fivethirtyeight')
# plt.style.use('grayscale')
# plt.style.use('seaborn-bright')
# plt.style.use('seaborn-notebook')
# plt.style.use('seaborn-pastel')
# plt.style.use('fast')
#cplt.style.use('ggplot')
import numpy as np

# %%
x = np.linspace(0,10,100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.plot(x, np.exp(-x))
plt.plot(x, - 1/100 * x**2)

# %%
# %%R
# x <- 42
# x
# Out:
# [1] 42
