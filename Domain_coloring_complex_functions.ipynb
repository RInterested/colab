# %% [markdown]
# From [https://notebook.community/empet/Math/DomainColoring](https://notebook.community/empet/Math/DomainColoring)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import hsv_to_rgb

# %%
def Hcomplex(z): # computes the hue corresponding to the complex number z
    H = np.angle(z) / (2 * np.pi) + 1
    return np.mod(H, 1)

# %%
# Example:
print(np.angle(-1j))
print(np.angle(-1j) / (2 * np.pi))
print(np.angle(-1j) / (2 * np.pi) + 1)
Hcomplex(-1j)
# Out:
# -1.5707963267948966
# -0.25
# 0.75
# 0.75

# %% [markdown]
# $g:[0,\infty)\to[0,1)$ is a strictly increasing function, chosen such that to be rapidly increasing near zero, in order to avoid too dark colors in the resulting image.

# %%
def g(x):
    return (1 - 1 / (1 + x**2))**0.05

# %%
x = np.arange(-1,4, 0.05)
y = np.arange(-1,3, 0.05)
x, y = np.meshgrid(x,y)

z = x + 1j * y # The identity function

H = Hcomplex(z)

V = g(np.absolute(z))

S = 0.9 * np.ones(H.shape)

HSV = np.dstack((H, S, V))
RGB = hsv_to_rgb(HSV)
plt.imshow(RGB, origin="lower", extent=[-1, 4, -1, 3])

# %% [markdown]
# `func_vals` evaluates the complex function at the nodes of a mesh grid. re and im are tuples, re=(a, b) and im=(c, d), defining the rectangular region. N is the number of discrete points per unit interval

# %%
def func_vals(f, re, im,  N):

    l = re[1]-re[0]
    h = im[1]-im[0]

    resL = N * l # horizontal resolution
    resH = N * h # vertical resolution

    x = np.linspace(re[0], re[1], int(resL))
    y = np.linspace(im[0], im[1], int(resH))

    x, y = np.meshgrid(x,y)

    z = x + 1j*y

    return f(z)

# %% [markdown]
# Classical domain coloring: w is the  array of values f(z); s is the constant saturation. The points mapped to infinity are colored with white: `hsv_to_rgb(0, 0, 1) = (1, 1, 1)= white'.

# %%
def domaincol_c(w, s):

    H = Hcomplex(w)
    S = s * np.ones(H.shape)
    modul = np.absolute(w)

    V = (1.0 - 1.0/( 1 + modul**2))**0.05

    HSV = np.dstack((H, S, V))
    RGB = hsv_to_rgb(HSV)
    return RGB

# %%
def plot_domain(color_func, f, re=[-1,1], im= [-1,1], title='', s=0.9, N=200, daxis=None):
    w = func_vals(f, re, im, N)
    domc = color_func(w, s)
    plt.xlabel("$\Re(z)$")
    plt.ylabel("$\Im(z)$")
    plt.title(title)
    if(daxis):
         plt.imshow(domc, origin="lower", extent=[re[0], re[1], im[0], im[1]])

    else:
        plt.imshow(domc, origin="lower")
        plt.axis('off')

# %%
plt.rcParams['figure.figsize'] = 10, 10

f = lambda z: (z**3 - 1)/z
plot_domain(domaincol_c, f, re=[-2, 2], im= [-2, 2], title='$f(z)=(z^3-1)/z$', daxis=True)

# %%
f = lambda z: np.cos(z)
plot_domain(domaincol_c, f, re=[-5, 5], im= [-2, 2], title='$f(z)=\cos(x)$', daxis=True)

# %%
f = lambda z: np.cos(z)**2
plot_domain(domaincol_c, f, re=[-5, 5], im= [-2, 2], title='$f(z)=\cos^2(x)$', daxis=True)

# %%
f = lambda z: np.cos(z)**5
plot_domain(domaincol_c, f, re=[-5, 5], im= [-2, 2], title='$f(z)=\cos^5(x)$', daxis=True)

# %%
f = lambda z: np.tan(z)
plot_domain(domaincol_c, f, re=[-5, 5], im= [-2, 2], title='$f(z)=\tan(x)$', daxis=True)

# %%
f = lambda z: np.log(z)
plot_domain(domaincol_c, f, re=[-2, 2], im= [-2, 2], title='$f(z)=\log(z)$', daxis=True)

# %%
f = lambda z: np.exp(z)
plot_domain(domaincol_c, f, re=[-10, 10], im= [-10, 10], title='$f(z)=\exp(z)$', daxis=True)

# %%
f = lambda z: z**(1/2)
plot_domain(domaincol_c, f, re=[-10, 10], im= [-10, 10], title='$f(z)=\sqrt{z}$', daxis=True)

# %% [markdown]
# Power functions go around the rainbow as many times as the exponent:
#
# $$z = r\,e^{i\theta} \mapsto z^2 = r \, e^{2i\theta}$$

# %%
f = lambda z: z**2
plot_domain(domaincol_c, f, re=[-10, 10], im= [-10, 10], title='$f(z)=z^2$', daxis=True)

# %%
f = lambda z: z**(-2) # A negative exponent changes the transitions from anticlockwise to clockwise
plot_domain(domaincol_c, f, re=[-10, 10], im= [-10, 10], title='$f(z)=z^2$', daxis=True)

# %% [markdown]
# ### ROOTS OF UNITY

# %%
f = lambda z: z**5 - 1
plot_domain(domaincol_c, f, re=[-4, 4], im= [-4, 4], title='Fifth roots of unity', daxis=True)

# %% [markdown]
# From [here](https://users.mai.liu.se/hanlu09/complex/domain_coloring.html):

# %%
f = lambda z: ( z + 2 )**2 * ( z - 1 - 2j ) * ( z + 1j )
plot_domain(domaincol_c, f, re=[-3, 3], im= [-3, 3], title='$f(z)={(z+2)}^2(z-1-2 i)(z+i)$', daxis=True)

# %%
f = lambda z: 1 / z
plot_domain(domaincol_c, f, re=[-3, 3], im= [-3, 3], title='$f(z)=1/z$', daxis=True)

# %%
f = lambda z: z
plot_domain(domaincol_c, f, re=[-3, 3], im= [-3, 3], title='$f(z)=z$', daxis=True)
